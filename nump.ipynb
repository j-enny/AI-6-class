# %%
import numpy as np
import pandas as pd

# %%
a = np.array([[2,3,4], [1, 3, 4], [2, 2, 2]

])

# %%
for cell in a:
    print (cell)
# Out:
# [2 3 4]
# [1 3 4]
# [2 2 2]

# %%
for row in a:
    print (row)
# Out:
# [2 3 4]
# [1 3 4]
# [2 2 2]

# %%
for row in a.flat:
    print (row)
# Out:
# 2
# 3
# 4
# 1
# 3
# 4
# 2
# 2
# 2

# %%
for cell in a:
    print (cell[2])
# Out:
# 4
# 4
# 2

# %%
df = pd.read_csv('UBAO.csv', nrows = 50)
df
# Out:
#           Date   Open   High    Low  Close    Volume  Adj Close
# 0    2/25/2011  32.29  33.09  32.27  10.00  20846500      32.95
# 1    2/24/2011  32.10  32.41  31.64  10.40  23416300      32.25
# 2    2/23/2011  32.55  32.65  32.02  10.50  22150000      32.18
# 3    2/22/2011  33.29  33.66  32.52  10.50  24878000      32.53
# 4    2/18/2011  33.02  33.71  32.91  10.50  25539300      33.68
# 5    2/17/2011  32.97  33.20  32.76  10.50  14568600      33.01
# 6    2/16/2011  32.85  33.14  32.61  10.53  15820900      33.11
# 7    2/15/2011  33.12  33.15  32.61  10.34  19330500      32.76
# 8    2/14/2011  33.29  33.54  33.24  10.88  16433900      33.29
# 9    2/11/2011  33.07  33.59  33.03  10.40  17396700      33.47
# 10   2/10/2011  32.78  33.26  32.66  10.44  17237700      33.26
# 11    2/9/2011  33.04  33.10  32.61  10.45  17110900      32.89
# 12    2/8/2011  33.02  33.16  32.72  10.31  15418100      33.03
# 13    2/7/2011  32.70  33.29  32.55  10.20  22780300      32.98
# ...
